# %%
import pandas as pd

data = pd.read_excel('raw_data/merged_data_test_task.xlsx')

# %%
data.head()
# Out:
#     Partner  Link for whatsapp        Brand          Model  \
# 0  Mr Good1                NaN  Range Rover    Vogue (new)
# 1  Mr Good1                NaN  Range Rover  Vogue (older)
# 2  Mr Good1                NaN         Audi            RS3
# 3  Mr Good1                NaN         Audi            RS6
# 4  Mr Good1                NaN     Mercedes  E Convertible
#
#    full price of car, euro  if 1-3 days\ euro per day  \
# 0                 120000.0                        600
# 1                 120000.0                        600
# 2                  75000.0                        375
# 3                 173000.0                        865
# 4                 110000.0                        550
#
#    if 4-6 days\ euro per day  if 7-9 days\ euro per day  \
# 0                     558.00                      516.0
# 1                     558.00                      516.0
# 2                     348.75                      322.5
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1756 entries, 0 to 1755
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Partner                        1756 non-null   object
#  1   Link for whatsapp              0 non-null      float64
#  2   Brand                          1756 non-null   object
#  3   Model                          1756 non-null   object
#  4   full price of car, euro        1755 non-null   float64
#  5   if 1-3 days\ euro per day      1756 non-null   int64
#  6   if 4-6 days\ euro per day      1756 non-null   float64
#  7   if 7-9 days\ euro per day      1756 non-null   float64
#  8   if 10-12 days\ euro per day    1756 non-null   float64
#  9   if 13-15 days\ euro per day    1756 non-null   float64
#  10  if 16-18 days\ euro per day    1756 non-null   float64
#  11  if 19-23 days \ euro per day   1756 non-null   float64
# ...

# %% [markdown]
# delating useless and empty columns

# %%
data = data.drop(columns=['Link for whatsapp','Additional info about car','Fleet','Partner','full price of car, euro'])

# %% [markdown]
# columns that use in response

# %%
data = data[['Brand','Model','if 1-3 days\ euro per day','Locations','Contact person']]

# %%
data[data['Model']=="RS6"]
# Out:
#      Brand Model  if 1-3 days\ euro per day               Locations  \
# 3     Audi   RS6                        865         Marbella, Spain
# 88    Audi   RS6                        865        Barcelona, Spain
# 99    AUDI   RS6                        865  Malaga - Madrid, Spain
# 143   Audi   RS6                        865  Madrid - Caribi, Spain
# 167   Audi   RS6                        865  Madrid - Malaga, Spain
# 312   Audi   RS6                        865  Bologna, Milano, Italy
# 393   Audi   RS6                        865             Roma, Italy
# 432   Audi   RS6                        865           Milano, Italy
# 440   Audi   RS6                        865             Roma, Italy
# 571   Audi   RS6                        865                     NaN
# 612   Audi   RS6                        865          Firenze, Italy
# 663   Audi   RS6                        865  Forte dei marmi, Italy
# 785   Audi   RS6                        865             Roma, Italy
# ...

# %% [markdown]
# save DataFrame to csv file

# %%
data.to_csv("data/data.csv")
